# %% [markdown]
# # Intro to Python

# %% [markdown]
# ## input and output

# %%
input()
# Out:
#  Hi There
# 'Hi There'

# %%
input ("please type your name")
# Out:
# please type your name Hannah
# 'Hannah '

# %%
print(" Hi there")
# Out:
#  Hi there

# %%
print("AAA""BBBB""CCCC")
# Out:
# AAABBBBCCCC

# %%
##Arithmetic
